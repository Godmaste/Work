# %%
# %%html
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>
# Out:
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %% [markdown]
# # Template 1

# %%
import satin

# %%
import pandas as pd
from IPython.display import display
from ipywidgets import HBox, VBox
import ipywidgets as widgets
from beakerx import *

file = open("image.png", "rb")
image = file.read()

html = widgets.HTML(
    value='<h3>Some Subheading</h3>'
    '<text>Using the widget layout functions HBox and VBox</text>'
    '<br>'
    '<text>to display the notebook in a presentable fashion</text>'
    '<br>'
    '<h4>Some smaller subheading</h4>'
    '<text>Contains some text, a button, a figure and a table </text>'
)

image = widgets.Image(
    value=image,
    format='png',
)

button = widgets.Button(
    description='Some Button',
    disabled=False,
    button_style='',
    tooltip='Click me',
    icon='check'
)

text = widgets.Text(
    value='Hello World',
    placeholder='Type something',
    description='',
    disabled=False
)

form1 = EasyForm("Form and Run")
form1.addTextField("first", 15)
form1['first'] = 'Beaker'
form1.addTextField("middle", 15)
form1.addTextField("last", 15)
form1.addButton("Go!", "run")

form2 = EasyForm("Form 2 and Run")
form2.addTextField("first", 15)
form2['first'] = 'Beaker'
form2.addTextField("middle", 15)
form2.addTextField("last", 15)
form2.addButton("Go!", "run")

table = widgets.Output()
with table:
    display(pd.read_csv('Book1.csv'))

l = list(open("z.txt"))

dp1 = widgets.Text(value = "", description = "Search: ")
dp2 = widgets.Dropdown(options = l)
combo = widgets.VBox([dp1, dp2])
def combobox(x):
    global dp1
    global dp2
    dp2.options = l
    search = dp1.value
    dp2.index = None #This line is very important for setting the values for widgets other than widget with observe method
    dp2.index = 0
    output = []
    for j in dp2.options:
        if search in j:
            output.append(j)
    if len(output) == 0:
        dp2.options = ["No Items Found"]
    else:
        dp2.options = output

emptywidget = widgets.Output()
            
dp1.observe(combobox)

# %%
satin.create_panel([[html, image, form1], [form2, emptywidget ,combo], [table]], #widgets
                   [[0, 0, 0], [0, 0, 0], [0]], #stretch 
                   [['top', 0, 'center'], [0, 0, 'center'], [0]], #vertical align
                   ['left', 'left', 'middle'], #horizontal align
                   0, 0, #height width (0, 0 for default)
                   [[[200,300],[250,350],[300,400]], [[0,0],[200,200],[200,500]], [[0,0]]] #widget [height, width]
                  )
# Out:
# VBox(children=(HBox(children=(HTML(value='<h3>Some Subheading</h3><text>Using the widget layout functions HBox…

# %%
# %%html
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();0
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
# Out:
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();0
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
